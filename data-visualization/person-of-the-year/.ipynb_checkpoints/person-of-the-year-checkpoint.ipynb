# %% [markdown]
# # Data visulization of Person of The Year Award

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(color_codes=True)

# %matplotlib inline

# %% [markdown]
# ## Loading csv

# %%
data = pd.read_csv("archive.csv", sep=",")
data.head()
# Out:
#    Year            Honor               Name        Country  Birth Year  \
# 0  1927  Man of the Year  Charles Lindbergh  United States      1902.0
# 1  1928  Man of the Year    Walter Chrysler  United States      1875.0
# 2  1929  Man of the Year      Owen D. Young  United States      1874.0
# 3  1930  Man of the Year     Mahatma Gandhi          India      1869.0
# 4  1931  Man of the Year       Pierre Laval         France      1883.0
#
#    Death Year                                              Title    Category  \
# 0      1974.0                                  US Air Mail Pilot         NaN
# 1      1940.0                                Founder of Chrysler   Economics
# 2      1962.0  Member of the German Reparations International...   Diplomacy
# 3      1948.0                                                NaN  Revolution
# 4      1945.0                           Prime Minister of France    Politics
#
#                            Context
# 0  First Solo Transatlantic Flight
# ...

# %% [markdown]
# ## Making a new attribute [Year Award]

# %%
data['Year Award'] = data['Year'] - data['Birth Year']
data.head()
# Out:
#    Year            Honor               Name        Country  Birth Year  \
# 0  1927  Man of the Year  Charles Lindbergh  United States      1902.0
# 1  1928  Man of the Year    Walter Chrysler  United States      1875.0
# 2  1929  Man of the Year      Owen D. Young  United States      1874.0
# 3  1930  Man of the Year     Mahatma Gandhi          India      1869.0
# 4  1931  Man of the Year       Pierre Laval         France      1883.0
#
#    Death Year                                              Title    Category  \
# 0      1974.0                                  US Air Mail Pilot         NaN
# 1      1940.0                                Founder of Chrysler   Economics
# 2      1962.0  Member of the German Reparations International...   Diplomacy
# 3      1948.0                                                NaN  Revolution
# 4      1945.0                           Prime Minister of France    Politics
#
#                            Context  Year Award
# ...

# %%
category_counts = data['Category'].value_counts()
category_counts
# Out:
# Politics        43
# War             20
# Economics        7
# Diplomacy        7
# Technology       5
# Revolution       5
# Science          4
# Space            4
# Philanthropy     3
# Religion         3
# Environment      1
# Media            1
# Name: Category, dtype: int64

# %%
category = category_counts.index
category
# Out:
# Index([u'Politics', u'War', u'Economics', u'Diplomacy', u'Technology',
#        u'Revolution', u'Science', u'Space', u'Philanthropy', u'Religion',
#        u'Environment', u'Media'],
#       dtype='object')

# %%
c_counts = category_counts.get_values()
c_counts
# Out:
# array([43, 20,  7,  7,  5,  5,  4,  4,  3,  3,  1,  1])

# %% [markdown]
# # Number of winners per category (Plot)

# %%
plt.xticks(rotation=70)
plt.xlabel('Category of the winners')
plt.ylabel('Number of winners')
plt.title('Number of winners per category', fontsize='15')
#plt.figure(figsize=(12,8))
barplot = sns.barplot(x=category, y=c_counts)

# %% [markdown]
# ## Group by country and category

# %%
country_category_group = data.groupby(['Country','Category']).size().unstack(fill_value=0)
country_category_group.plot(kind='bar',legend=True,figsize=(13,8), stacked=True, colormap='cubehelix', rot=70, fontsize=12, grid=True)

# %% [markdown]
# ## Same plot (less USA)

# %%
countries_less_usa = data[data['Country'] != 'United States']

# %%
category_groupby_less_usa = countries_less_usa.groupby(['Country', 'Category']).size().unstack(fill_value=0)
category_groupby_less_usa.plot(kind='bar', stacked=True, figsize=(13,8), colormap='cubehelix', legend=True, rot=70, fontsize=12)

# %% [markdown]
# ## Year Award and your category

# %%
x_age_prize = data['Year Award']
y_category = data['Category']
sns.stripplot(x=x_age_prize, y=y_category, jitter=True, orient='h', size=9)

# %% [markdown]
# ## New attribute: Age Category, according no range values

# %%
max_age = data['Year Award'].max()
max_age
bins = [18, 25, 35, 60, max_age + 1]
age_rank = ['Youth', 'Yought Adult', 'Middle Aged', 'Senior']

data['Age Category'] = pd.cut(data['Year Award'], bins, labels=age_rank)
data.head()
# Out:
#    Year            Honor               Name        Country  Birth Year  \
# 0  1927  Man of the Year  Charles Lindbergh  United States      1902.0
# 1  1928  Man of the Year    Walter Chrysler  United States      1875.0
# 2  1929  Man of the Year      Owen D. Young  United States      1874.0
# 3  1930  Man of the Year     Mahatma Gandhi          India      1869.0
# 4  1931  Man of the Year       Pierre Laval         France      1883.0
#
#    Death Year                                              Title    Category  \
# 0      1974.0                                  US Air Mail Pilot         NaN
# 1      1940.0                                Founder of Chrysler   Economics
# 2      1962.0  Member of the German Reparations International...   Diplomacy
# 3      1948.0                                                NaN  Revolution
# 4      1945.0                           Prime Minister of France    Politics
#
#                            Context  Year Award Age Category
# ...

# %% [markdown]
# ## Age Category, pie plot

# %%
age_category_counts = data['Age Category'].value_counts()
age_category_counts.plot(kind="pie", figsize=(7,7), autopct='%.2f', colors=['r', 'g', 'b', 'c'], legend=True)

# %% [markdown]
# ## Winners per country, less USA

# %%
winners_per_country_less_usa = data[data['Country'] != 'United States']
winners_per_country_less_usa = winners_per_country_less_usa['Country'].value_counts()
winners_per_country_less_usa.plot(kind='pie', figsize=(10, 10), autopct='%.2f')

# %% [markdown]
# ## Using seaborn

# %%
sns.jointplot(x=data['Year'], y=data['Year Award'], kind='scatter')

# %%
sns.jointplot(x=data['Year'], y=data['Year Award'], kind='kde')

# %% [markdown]
# ## Group by Honor and Age Category

# %%
honor_and_category_gb = data.groupby(['Honor', 'Age Category']).size().unstack(fill_value=0)
honor_and_category_gb.plot(kind='barh', figsize=(8,8), legend=True, stacked=True, colormap='cubehelix', fontsize=12, title='Honor x Age Category')
